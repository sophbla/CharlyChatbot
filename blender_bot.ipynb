# %%
! pip install transformers gradio -q

# %%
from transformers import BlenderbotTokenizer, BlenderbotForConditionalGeneration
import torch
import gradio as gr

# %%
tokenizer = BlenderbotTokenizer.from_pretrained("facebook/blenderbot-400M-distill")
model = BlenderbotForConditionalGeneration.from_pretrained("facebook/blenderbot-400M-distill")

# %%
def predict(input, history=[]):

    if len(history) != 0:
      input = ' '.join((*history, input))

    inputs_token = tokenizer(input, return_tensors='pt')
    # print(inputs_token)

    res = model.generate(**inputs_token)
    outputs = tokenizer.decode(res[0])

    history.append(' '.join((input, outputs)))

    return outputs, history

# %%
input1 = 'Hi. I feel sad and I would love to get some help.'

# %%
response1, history1 = predict(input1)
print(response1)
# Out:
# <s> I'm sorry to hear that. I hope you feel better soon. What's going on?</s>

# %%
print(history1)
# Out:
# ["Hi. I feel sad and I would love to get some help. <s> I'm sorry to hear that. I hope you feel better soon. What's going on?</s>"]

# %%
input2 = 'Can you help me feeling better?'

# %%
response2, history2 = predict(input2, history1)
print(response2)
# Out:
# <s> I wish I could, but I can't afford to go to the doctor right now. </s>
